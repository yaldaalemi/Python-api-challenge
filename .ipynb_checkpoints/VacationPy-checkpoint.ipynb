# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0        rikitea -23.1203 -134.9692    297.26        81         100
# 1        1       hermanus -34.4187   19.2345    283.60        71          30
# 2        2      nishihara  26.1842  127.7558    294.75        64          75
# 3        3    grand gaube -20.0064   57.6608    300.03        70          53
# 4        4  mar del plata -38.0023  -57.5575    294.16        73           0
#
#    Wind Speed Country
# 0        6.06      PF
# 1        2.07      ZA
# 2       10.29      JP
# 3        4.92      MU
# 4        5.66      AR

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
locations = city_data_df[["Lat", "Lng"]]
Humidity = city_data_df["Humidity"]
plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    size = "Humidity"
)
# Display the map
plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
filtered_df = city_data_df.loc[(city_data_df["Max Temp"] <= 300.15) & (city_data_df["Max Temp"] >= 294.15) \
                             & (city_data_df["Wind Speed"] <= 4.5) & (city_data_df["Cloudiness"] == 0)] 

# Drop any rows with null values
filter_df = filtered_df.dropna()

# Display sample data
filter_df.head()
# Out:
#      City_ID       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 12        12  busselton -33.6500  115.3333    296.34        37           0
# 69        69        sur  22.5667   59.5289    297.08        55           0
# 135      135   west bay  19.3667  -81.4167    299.26        73           0
# 209      209      seoni  22.0833   79.5333    294.21        44           0
# 284      284   pochutla  15.7432  -96.4661    296.38        68           0
#
#      Wind Speed Country
# 12         4.15      AU
# 69         0.97      OM
# 135        0.89      KY
# 209        4.05      IN
# 284        1.49      MX

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = filter_df.copy()
hotel_df.drop(["City_ID", "Wind Speed","Cloudiness","Max Temp"], axis=1)

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"]=""

# Display sample data
hotel_df.head()
# Out:
#      City_ID       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 12        12  busselton -33.6500  115.3333    296.34        37           0
# 69        69        sur  22.5667   59.5289    297.08        55           0
# 135      135   west bay  19.3667  -81.4167    299.26        73           0
# 209      209      seoni  22.0833   79.5333    294.21        44           0
# 284      284   pochutla  15.7432  -96.4661    296.38        68           0
#
#      Wind Speed Country Hotel Name
# 12         4.15      AU
# 69         0.97      OM
# 135        0.89      KY
# 209        4.05      IN
# 284        1.49      MX

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
radius = 10000
params = {
    "radius": radius,
    "apiKey": geoapify_key,
    "categories": "accommodation.hotel"
}
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    Lat = row["Lat"]
    Lng = row["Lng"]
    params["filter"] = f"circle:{Lng},{Lat},{radius}"
    params["bias"] = f"proximity:{Lng},{Lat}"
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = requests.get(base_url, params=params).json()
    
name_address["features"][0]["properties"]["name"]
# Out:
# 'Hotel Argentina 307'

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "radius": radius,
    "apiKey": geoapify_key,
    "categories": "accommodation.hotel"
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    Lat = row["Lat"]
    Lng = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{Lng},{Lat},{radius}"
    params["bias"] = f"proximity:{Lng},{Lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = requests.get(base_url, params=params).json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# busselton - nearest hotel: Broadwater Beach Resort
# sur - nearest hotel: Sur Hotel
# west bay - nearest hotel: Bonnie's Arch
# seoni - nearest hotel: No hotel found
# pochutla - nearest hotel: Hotel El Patio
# cape canaveral - nearest hotel: Holiday Inn Club Vacations Cape Canaveral Beach Resort
# tura - nearest hotel: No hotel found
# villa maria - nearest hotel: Gran Hotel Orión
# key west - nearest hotel: Harborside Hotel & Marina
# rosario - nearest hotel: Fontana Suites
# mercedes - nearest hotel: Gran Hotel Mercedes
# myitkyina - nearest hotel: New Light Hotel
# neuquen - nearest hotel: Hotel Argentina 307
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 12        12       busselton -33.6500  115.3333    296.34        37
# 69        69             sur  22.5667   59.5289    297.08        55
# 135      135        west bay  19.3667  -81.4167    299.26        73
# 209      209           seoni  22.0833   79.5333    294.21        44
# 284      284        pochutla  15.7432  -96.4661    296.38        68
# 342      342  cape canaveral  28.4058  -80.6048    295.93        85
# 370      370            tura  25.5198   90.2201    296.21        55
# 423      423     villa maria -32.4075  -63.2402    297.49        43
# 435      435        key west  24.5557  -81.7826    300.15        79
# 447      447         rosario -32.9468  -60.6393    299.96        56
# 525      525        mercedes -34.6515  -59.4307    298.51        60
# 546      546       myitkyina  25.3833   97.4000    297.26        34
# 552      552         neuquen -38.9516  -68.0591    294.57        40
#
#      Cloudiness  Wind Speed Country  \
# 12            0        4.15      AU
# 69            0        0.97      OM
# 135           0        0.89      KY
# 209           0        4.05      IN
# 284           0        1.49      MX
# 342           0        1.54      US
# 370           0        0.17      IN
# 423           0        4.17      AR
# 435           0        3.09      US
# 447           0        3.60      AR
# 525           0        4.16      AR
# 546           0        0.99      MM
# 552           0        2.57      AR
#
#                                             Hotel Name
# 12                             Broadwater Beach Resort
# 69                                           Sur Hotel
# 135                                      Bonnie's Arch
# 209                                     No hotel found
# 284                                     Hotel El Patio
# 342  Holiday Inn Club Vacations Cape Canaveral Beac...
# 370                                     No hotel found
# 423                                   Gran Hotel Orión
# 435                          Harborside Hotel & Marina
# 447                                     Fontana Suites
# 525                                Gran Hotel Mercedes
# 546                                    New Light Hotel
# 552                                Hotel Argentina 307

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
