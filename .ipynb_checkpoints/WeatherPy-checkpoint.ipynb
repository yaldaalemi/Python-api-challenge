# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 611

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key
#url = "https://api.openweathermap.org/data/3.0/onecall?appid=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []
city_lat = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lon = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds =  city_weather["clouds"]["all"]
        city_wind =  city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the City information into city_data list
        city_data.append({"City": city, "Lat": city_lat,\
                          "Lng": city_lon, \
                          "Max Temp": city_max_temp,\
                          "Humidity": city_humidity,\
                          "Cloudiness": city_clouds,\
                          "Wind Speed": city_wind,\
                          "Country": city_country,})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | nishihara
# Processing Record 4 of Set 1 | grand gaube
# Processing Record 5 of Set 1 | mar del plata
# Processing Record 6 of Set 1 | san patricio
# Processing Record 7 of Set 1 | nuuk
# Processing Record 8 of Set 1 | omsukchan
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | kaitangata
# Processing Record 18 of Set 1 | orlik
# Processing Record 19 of Set 1 | longyearbyen
# Processing Record 20 of Set 1 | sao joao de pirabas
# Processing Record 21 of Set 1 | goderich
# Processing Record 22 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 1 | charters towers
# Processing Record 24 of Set 1 | guerrero negro
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | bathsheba
# Processing Record 27 of Set 1 | thompson
# Processing Record 28 of Set 1 | lompoc
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | solnechnyy
# Processing Record 31 of Set 1 | saint-augustin
# Processing Record 32 of Set 1 | ponta do sol
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | kurtalan
# Processing Record 36 of Set 1 | sungaipenuh
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | lorengau
# Processing Record 40 of Set 1 | bilma
# Processing Record 41 of Set 1 | ivanovice na hane
# Processing Record 42 of Set 1 | krasnyy yar
# Processing Record 43 of Set 1 | bauchi
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | sabang
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | wilmington
# Processing Record 48 of Set 1 | waldkraiburg
# Processing Record 49 of Set 1 | san vicente
# Processing Record 50 of Set 1 | cabo san lucas
# Processing Record 0 of Set 2 | mataura
# Processing Record 1 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 2 | ilulissat
# Processing Record 3 of Set 2 | vardo
# Processing Record 4 of Set 2 | clyde river
# Processing Record 5 of Set 2 | chuy
# Processing Record 6 of Set 2 | wadi musa
# Processing Record 7 of Set 2 | cherskiy
# Processing Record 8 of Set 2 | beringovskiy
# Processing Record 9 of Set 2 | omboue
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | leh
# Processing Record 12 of Set 2 | portland
# Processing Record 13 of Set 2 | cayenne
# Processing Record 14 of Set 2 | norman wells
# Processing Record 15 of Set 2 | mimoso do sul
# Processing Record 16 of Set 2 | ust-barguzin
# Processing Record 17 of Set 2 | georgiyevka
# Processing Record 18 of Set 2 | puerto lopez
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | bijie
# Processing Record 21 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 2 | lasa
# Processing Record 23 of Set 2 | mantua
# Processing Record 24 of Set 2 | pevek
# Processing Record 25 of Set 2 | po
# City not found. Skipping...
# Processing Record 26 of Set 2 | sur
# Processing Record 27 of Set 2 | andenes
# Processing Record 28 of Set 2 | bredasdorp
# Processing Record 29 of Set 2 | provideniya
# Processing Record 30 of Set 2 | faanui
# Processing Record 31 of Set 2 | biak
# Processing Record 32 of Set 2 | kapaa
# Processing Record 33 of Set 2 | chinchani
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | aktash
# Processing Record 36 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 2 | chumikan
# Processing Record 38 of Set 2 | kozhevnikovo
# Processing Record 39 of Set 2 | makakilo city
# Processing Record 40 of Set 2 | stromness
# Processing Record 41 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 2 | trinidad
# Processing Record 43 of Set 2 | rawson
# Processing Record 44 of Set 2 | haimen
# Processing Record 45 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 2 | vanimo
# Processing Record 47 of Set 2 | tongzhou
# Processing Record 48 of Set 2 | marsa matruh
# Processing Record 49 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 0 of Set 3 | guider
# Processing Record 1 of Set 3 | mahebourg
# Processing Record 2 of Set 3 | fortuna
# Processing Record 3 of Set 3 | arraial do cabo
# Processing Record 4 of Set 3 | nabire
# Processing Record 5 of Set 3 | cam ranh
# Processing Record 6 of Set 3 | nome
# Processing Record 7 of Set 3 | bambari
# Processing Record 8 of Set 3 | avarua
# Processing Record 9 of Set 3 | albany
# Processing Record 10 of Set 3 | karnobat
# Processing Record 11 of Set 3 | puerto ayora
# Processing Record 12 of Set 3 | wajima
# Processing Record 13 of Set 3 | aasiaat
# Processing Record 14 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 15 of Set 3 | ariquemes
# Processing Record 16 of Set 3 | castro
# Processing Record 17 of Set 3 | buala
# Processing Record 18 of Set 3 | cape town
# Processing Record 19 of Set 3 | barra patuca
# Processing Record 20 of Set 3 | marienburg
# Processing Record 21 of Set 3 | benguela
# Processing Record 22 of Set 3 | vaini
# Processing Record 23 of Set 3 | gashua
# Processing Record 24 of Set 3 | saint-philippe
# Processing Record 25 of Set 3 | bandarbeyla
# Processing Record 26 of Set 3 | nikolskoye
# Processing Record 27 of Set 3 | constitucion
# Processing Record 28 of Set 3 | seoul
# Processing Record 29 of Set 3 | sao felix do xingu
# Processing Record 30 of Set 3 | pangody
# Processing Record 31 of Set 3 | mayo
# Processing Record 32 of Set 3 | sao joao da boa vista
# Processing Record 33 of Set 3 | kahului
# Processing Record 34 of Set 3 | pitimbu
# Processing Record 35 of Set 3 | khasan
# Processing Record 36 of Set 3 | benjamin constant
# Processing Record 37 of Set 3 | mareeba
# Processing Record 38 of Set 3 | upernavik
# Processing Record 39 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 3 | olinda
# Processing Record 41 of Set 3 | lincoln
# Processing Record 42 of Set 3 | road town
# Processing Record 43 of Set 3 | belyy yar
# Processing Record 44 of Set 3 | mildura
# Processing Record 45 of Set 3 | manggar
# Processing Record 46 of Set 3 | morondava
# Processing Record 47 of Set 3 | colac
# Processing Record 48 of Set 3 | west bay
# Processing Record 49 of Set 3 | yellowknife
# Processing Record 0 of Set 4 | tiksi
# Processing Record 1 of Set 4 | ugoofaaru
# Processing Record 2 of Set 4 | umm jarr
# City not found. Skipping...
# Processing Record 3 of Set 4 | half moon bay
# Processing Record 4 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 5 of Set 4 | agua branca
# Processing Record 6 of Set 4 | ahar
# Processing Record 7 of Set 4 | sao joao da barra
# Processing Record 8 of Set 4 | cienfuegos
# Processing Record 9 of Set 4 | naze
# Processing Record 10 of Set 4 | chokurdakh
# Processing Record 11 of Set 4 | qaanaaq
# Processing Record 12 of Set 4 | ribeira grande
# Processing Record 13 of Set 4 | cidreira
# Processing Record 14 of Set 4 | linjiang
# Processing Record 15 of Set 4 | carnarvon
# Processing Record 16 of Set 4 | litovko
# Processing Record 17 of Set 4 | georgetown
# Processing Record 18 of Set 4 | segou
# Processing Record 19 of Set 4 | tuatapere
# Processing Record 20 of Set 4 | anori
# Processing Record 21 of Set 4 | fairbanks
# Processing Record 22 of Set 4 | bethel
# Processing Record 23 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 4 | gat
# Processing Record 25 of Set 4 | new norfolk
# Processing Record 26 of Set 4 | mutis
# Processing Record 27 of Set 4 | gorontalo
# Processing Record 28 of Set 4 | maragogi
# Processing Record 29 of Set 4 | tambacounda
# Processing Record 30 of Set 4 | saldanha
# Processing Record 31 of Set 4 | saskylakh
# Processing Record 32 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 4 | mikhaylovsk
# Processing Record 34 of Set 4 | tateyama
# Processing Record 35 of Set 4 | hasaki
# Processing Record 36 of Set 4 | smirnykh
# Processing Record 37 of Set 4 | urumqi
# Processing Record 38 of Set 4 | fort nelson
# Processing Record 39 of Set 4 | talnakh
# Processing Record 40 of Set 4 | severo-kurilsk
# Processing Record 41 of Set 4 | comodoro rivadavia
# Processing Record 42 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 43 of Set 4 | zaraza
# Processing Record 44 of Set 4 | ogulin
# Processing Record 45 of Set 4 | taloqan
# Processing Record 46 of Set 4 | libreville
# Processing Record 47 of Set 4 | verdalsora
# City not found. Skipping...
# Processing Record 48 of Set 4 | sumbe
# Processing Record 49 of Set 4 | marawi
# Processing Record 0 of Set 5 | henties bay
# Processing Record 1 of Set 5 | gigmoto
# Processing Record 2 of Set 5 | abu samrah
# Processing Record 3 of Set 5 | manhumirim
# Processing Record 4 of Set 5 | verkhnetulomskiy
# Processing Record 5 of Set 5 | camacha
# Processing Record 6 of Set 5 | katsuura
# Processing Record 7 of Set 5 | sioux lookout
# Processing Record 8 of Set 5 | valdivia
# Processing Record 9 of Set 5 | vasilsursk
# Processing Record 10 of Set 5 | hithadhoo
# Processing Record 11 of Set 5 | emerald
# Processing Record 12 of Set 5 | satao
# Processing Record 13 of Set 5 | moroni
# Processing Record 14 of Set 5 | sitka
# Processing Record 15 of Set 5 | marzuq
# Processing Record 16 of Set 5 | kruisfontein
# Processing Record 17 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 5 | gurupa
# Processing Record 20 of Set 5 | iqaluit
# Processing Record 21 of Set 5 | azuaga
# Processing Record 22 of Set 5 | lang son
# Processing Record 23 of Set 5 | novyy urengoy
# Processing Record 24 of Set 5 | port hardy
# Processing Record 25 of Set 5 | okha
# Processing Record 26 of Set 5 | whitefish
# Processing Record 27 of Set 5 | susanville
# Processing Record 28 of Set 5 | lata
# Processing Record 29 of Set 5 | iraucuba
# Processing Record 30 of Set 5 | seoni
# Processing Record 31 of Set 5 | haines junction
# Processing Record 32 of Set 5 | ketchikan
# Processing Record 33 of Set 5 | chiang khong
# Processing Record 34 of Set 5 | antofagasta
# Processing Record 35 of Set 5 | minab
# Processing Record 36 of Set 5 | poso
# Processing Record 37 of Set 5 | bambous virieux
# Processing Record 38 of Set 5 | nouadhibou
# Processing Record 39 of Set 5 | dabakala
# Processing Record 40 of Set 5 | kango
# Processing Record 41 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 5 | dikson
# Processing Record 43 of Set 5 | kiama
# Processing Record 44 of Set 5 | sandakan
# Processing Record 45 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 5 | sambava
# Processing Record 47 of Set 5 | tarakan
# Processing Record 48 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 5 | korla
# Processing Record 0 of Set 6 | almaznyy
# Processing Record 1 of Set 6 | jackson
# Processing Record 2 of Set 6 | srirampur
# Processing Record 3 of Set 6 | zyryanka
# Processing Record 4 of Set 6 | vila velha
# Processing Record 5 of Set 6 | meulaboh
# Processing Record 6 of Set 6 | mongoumba
# Processing Record 7 of Set 6 | devonport
# Processing Record 8 of Set 6 | shache
# Processing Record 9 of Set 6 | kavieng
# Processing Record 10 of Set 6 | kavaratti
# Processing Record 11 of Set 6 | hambantota
# Processing Record 12 of Set 6 | sakakah
# Processing Record 13 of Set 6 | bonavista
# Processing Record 14 of Set 6 | leningradskiy
# Processing Record 15 of Set 6 | agadez
# Processing Record 16 of Set 6 | ostrovnoy
# Processing Record 17 of Set 6 | jinxiang
# Processing Record 18 of Set 6 | saint-francois
# Processing Record 19 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 20 of Set 6 | russell
# Processing Record 21 of Set 6 | kuala terengganu
# Processing Record 22 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 6 | yar-sale
# Processing Record 24 of Set 6 | paliambela
# Processing Record 25 of Set 6 | ancud
# Processing Record 26 of Set 6 | touros
# Processing Record 27 of Set 6 | luderitz
# Processing Record 28 of Set 6 | high level
# Processing Record 29 of Set 6 | karratha
# Processing Record 30 of Set 6 | san cristobal
# Processing Record 31 of Set 6 | vestmannaeyjar
# Processing Record 32 of Set 6 | bubaque
# Processing Record 33 of Set 6 | quatre cocos
# Processing Record 34 of Set 6 | dukat
# Processing Record 35 of Set 6 | preeceville
# Processing Record 36 of Set 6 | kaniama
# Processing Record 37 of Set 6 | nisia floresta
# Processing Record 38 of Set 6 | suez
# Processing Record 39 of Set 6 | saint anthony
# Processing Record 40 of Set 6 | faya
# Processing Record 41 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 6 | geresk
# City not found. Skipping...
# Processing Record 43 of Set 6 | port macquarie
# Processing Record 44 of Set 6 | turkistan
# Processing Record 45 of Set 6 | cabadiangan
# Processing Record 46 of Set 6 | krasnokamensk
# Processing Record 47 of Set 6 | wittstock
# Processing Record 48 of Set 6 | victoria point
# Processing Record 49 of Set 6 | tilichiki
# Processing Record 0 of Set 7 | broome
# Processing Record 1 of Set 7 | mount isa
# Processing Record 2 of Set 7 | airai
# Processing Record 3 of Set 7 | alexandria
# Processing Record 4 of Set 7 | victoria
# Processing Record 5 of Set 7 | khatanga
# Processing Record 6 of Set 7 | sao filipe
# Processing Record 7 of Set 7 | galesong
# Processing Record 8 of Set 7 | shenjiamen
# Processing Record 9 of Set 7 | yatou
# Processing Record 10 of Set 7 | voloshka
# Processing Record 11 of Set 7 | natal
# Processing Record 12 of Set 7 | pochutla
# Processing Record 13 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 7 | lamu
# Processing Record 15 of Set 7 | clarence town
# Processing Record 16 of Set 7 | alice springs
# Processing Record 17 of Set 7 | brumunddal
# Processing Record 18 of Set 7 | verkhoyansk
# Processing Record 19 of Set 7 | sampit
# Processing Record 20 of Set 7 | brownsville
# Processing Record 21 of Set 7 | bilibino
# Processing Record 22 of Set 7 | bengkulu
# Processing Record 23 of Set 7 | keflavik
# Processing Record 24 of Set 7 | lumphat
# Processing Record 25 of Set 7 | kangaba
# Processing Record 26 of Set 7 | klaksvik
# Processing Record 27 of Set 7 | krasnoznamensk
# Processing Record 28 of Set 7 | waddan
# Processing Record 29 of Set 7 | moiyabana
# City not found. Skipping...
# Processing Record 30 of Set 7 | vila
# Processing Record 31 of Set 7 | pangnirtung
# Processing Record 32 of Set 7 | kalmunai
# Processing Record 33 of Set 7 | torbay
# Processing Record 34 of Set 7 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 35 of Set 7 | komsomolskiy
# Processing Record 36 of Set 7 | ipeti
# City not found. Skipping...
# Processing Record 37 of Set 7 | cicero dantas
# Processing Record 38 of Set 7 | chiang klang
# Processing Record 39 of Set 7 | la rioja
# Processing Record 40 of Set 7 | tapachula
# Processing Record 41 of Set 7 | opuwo
# Processing Record 42 of Set 7 | gornyak
# Processing Record 43 of Set 7 | shingu
# Processing Record 44 of Set 7 | rabo de peixe
# Processing Record 45 of Set 7 | prabumulih
# Processing Record 46 of Set 7 | quelimane
# Processing Record 47 of Set 7 | saldana
# Processing Record 48 of Set 7 | poronaysk
# Processing Record 49 of Set 7 | zelenets
# Processing Record 0 of Set 8 | hirara
# Processing Record 1 of Set 8 | sabha
# Processing Record 2 of Set 8 | pemberton
# Processing Record 3 of Set 8 | mulchen
# Processing Record 4 of Set 8 | san quintin
# Processing Record 5 of Set 8 | kodiak
# Processing Record 6 of Set 8 | placido de castro
# Processing Record 7 of Set 8 | lixourion
# Processing Record 8 of Set 8 | asau
# Processing Record 9 of Set 8 | lufilufi
# Processing Record 10 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 8 | ryazanovskiy
# Processing Record 12 of Set 8 | nagato
# Processing Record 13 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 14 of Set 8 | alenquer
# Processing Record 15 of Set 8 | porangatu
# Processing Record 16 of Set 8 | gold coast
# Processing Record 17 of Set 8 | zima
# Processing Record 18 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 8 | vila franca do campo
# Processing Record 20 of Set 8 | plast
# Processing Record 21 of Set 8 | boden
# Processing Record 22 of Set 8 | evensk
# Processing Record 23 of Set 8 | moose factory
# Processing Record 24 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 25 of Set 8 | suba
# Processing Record 26 of Set 8 | flin flon
# Processing Record 27 of Set 8 | tazovskiy
# Processing Record 28 of Set 8 | cape canaveral
# Processing Record 29 of Set 8 | pryozerne
# Processing Record 30 of Set 8 | lingyuan
# Processing Record 31 of Set 8 | chatrapur
# Processing Record 32 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 33 of Set 8 | baykit
# Processing Record 34 of Set 8 | tabuny
# Processing Record 35 of Set 8 | yanchukan
# City not found. Skipping...
# Processing Record 36 of Set 8 | raudeberg
# Processing Record 37 of Set 8 | boulder city
# Processing Record 38 of Set 8 | bonthe
# Processing Record 39 of Set 8 | seymchan
# Processing Record 40 of Set 8 | gimli
# Processing Record 41 of Set 8 | batagay-alyta
# Processing Record 42 of Set 8 | slave lake
# Processing Record 43 of Set 8 | bardiyah
# Processing Record 44 of Set 8 | asandh
# Processing Record 45 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 8 | labuhan
# Processing Record 47 of Set 8 | ixtapa
# Processing Record 48 of Set 8 | jiroft
# City not found. Skipping...
# Processing Record 49 of Set 8 | chiusi
# Processing Record 0 of Set 9 | bambanglipuro
# Processing Record 1 of Set 9 | muros
# Processing Record 2 of Set 9 | killybegs
# Processing Record 3 of Set 9 | svetlogorsk
# Processing Record 4 of Set 9 | pryazha
# Processing Record 5 of Set 9 | coahuayana
# Processing Record 6 of Set 9 | kargopol
# Processing Record 7 of Set 9 | kinablangan
# Processing Record 8 of Set 9 | oussouye
# Processing Record 9 of Set 9 | vukovar
# Processing Record 10 of Set 9 | tura
# Processing Record 11 of Set 9 | turukhansk
# Processing Record 12 of Set 9 | vao
# Processing Record 13 of Set 9 | yerbogachen
# Processing Record 14 of Set 9 | thinadhoo
# Processing Record 15 of Set 9 | puerto ayacucho
# Processing Record 16 of Set 9 | tukrah
# Processing Record 17 of Set 9 | khani
# Processing Record 18 of Set 9 | luanda
# Processing Record 19 of Set 9 | kieta
# Processing Record 20 of Set 9 | venice
# Processing Record 21 of Set 9 | mao
# Processing Record 22 of Set 9 | tumbi
# Processing Record 23 of Set 9 | hualmay
# Processing Record 24 of Set 9 | weihe
# Processing Record 25 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 26 of Set 9 | nayoro
# Processing Record 27 of Set 9 | vestmanna
# Processing Record 28 of Set 9 | oktyabrskoye
# Processing Record 29 of Set 9 | port-gentil
# Processing Record 30 of Set 9 | eyl
# Processing Record 31 of Set 9 | kropotkin
# Processing Record 32 of Set 9 | chesterfield
# Processing Record 33 of Set 9 | arti
# Processing Record 34 of Set 9 | yeppoon
# Processing Record 35 of Set 9 | carikar
# City not found. Skipping...
# Processing Record 36 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 9 | ubinskoye
# Processing Record 38 of Set 9 | carahue
# Processing Record 39 of Set 9 | barhi
# Processing Record 40 of Set 9 | dzhebariki-khaya
# Processing Record 41 of Set 9 | mezen
# Processing Record 42 of Set 9 | naushki
# Processing Record 43 of Set 9 | eureka
# Processing Record 44 of Set 9 | tottori
# Processing Record 45 of Set 9 | saint-pierre
# Processing Record 46 of Set 9 | souillac
# Processing Record 47 of Set 9 | bud
# Processing Record 48 of Set 9 | san rafael
# Processing Record 49 of Set 9 | dongsheng
# Processing Record 0 of Set 10 | deloraine
# Processing Record 1 of Set 10 | plover
# Processing Record 2 of Set 10 | farmington
# Processing Record 3 of Set 10 | isangel
# Processing Record 4 of Set 10 | belaya gora
# Processing Record 5 of Set 10 | mehamn
# Processing Record 6 of Set 10 | vostok
# Processing Record 7 of Set 10 | kulhudhuffushi
# Processing Record 8 of Set 10 | hrodna
# Processing Record 9 of Set 10 | conakry
# Processing Record 10 of Set 10 | yulara
# Processing Record 11 of Set 10 | dingle
# Processing Record 12 of Set 10 | kirgiz-miyaki
# Processing Record 13 of Set 10 | caluquembe
# Processing Record 14 of Set 10 | ulladulla
# Processing Record 15 of Set 10 | roald
# Processing Record 16 of Set 10 | villa maria
# Processing Record 17 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 18 of Set 10 | itapeva
# Processing Record 19 of Set 10 | sao mateus do maranhao
# Processing Record 20 of Set 10 | liverpool
# Processing Record 21 of Set 10 | kotelnich
# Processing Record 22 of Set 10 | kapoeta
# Processing Record 23 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 10 | villa del rosario
# Processing Record 25 of Set 10 | qurunbaliyah
# City not found. Skipping...
# Processing Record 26 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 27 of Set 10 | nacala
# Processing Record 28 of Set 10 | visconde do rio branco
# Processing Record 29 of Set 10 | severo-yeniseyskiy
# Processing Record 30 of Set 10 | aras
# Processing Record 31 of Set 10 | santa cruz cabralia
# Processing Record 32 of Set 10 | key west
# Processing Record 33 of Set 10 | avera
# Processing Record 34 of Set 10 | tsabong
# Processing Record 35 of Set 10 | hofn
# Processing Record 36 of Set 10 | halifax
# Processing Record 37 of Set 10 | jacqueville
# Processing Record 38 of Set 10 | sivakasi
# Processing Record 39 of Set 10 | batemans bay
# Processing Record 40 of Set 10 | tekeli
# Processing Record 41 of Set 10 | arauco
# Processing Record 42 of Set 10 | bereznik
# Processing Record 43 of Set 10 | willowmore
# Processing Record 44 of Set 10 | rosario
# Processing Record 45 of Set 10 | verkhnyaya toyma
# Processing Record 46 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 10 | ceres
# Processing Record 48 of Set 10 | pimentel
# Processing Record 49 of Set 10 | zhigansk
# Processing Record 0 of Set 11 | codrington
# Processing Record 1 of Set 11 | muroto
# Processing Record 2 of Set 11 | muhos
# Processing Record 3 of Set 11 | baruun-urt
# Processing Record 4 of Set 11 | mosquera
# Processing Record 5 of Set 11 | laguna
# Processing Record 6 of Set 11 | ahipara
# Processing Record 7 of Set 11 | aktau
# Processing Record 8 of Set 11 | little current
# Processing Record 9 of Set 11 | bowen
# Processing Record 10 of Set 11 | anadyr
# Processing Record 11 of Set 11 | esperance
# Processing Record 12 of Set 11 | hamilton
# Processing Record 13 of Set 11 | phangnga
# Processing Record 14 of Set 11 | ukiah
# Processing Record 15 of Set 11 | coihueco
# Processing Record 16 of Set 11 | tarso
# Processing Record 17 of Set 11 | lithakia
# Processing Record 18 of Set 11 | porto santo
# Processing Record 19 of Set 11 | aksarka
# Processing Record 20 of Set 11 | san blas
# Processing Record 21 of Set 11 | marsh harbour
# Processing Record 22 of Set 11 | sumenep
# Processing Record 23 of Set 11 | okhotsk
# Processing Record 24 of Set 11 | hailey
# Processing Record 25 of Set 11 | kirakira
# Processing Record 26 of Set 11 | trelew
# Processing Record 27 of Set 11 | del rio
# Processing Record 28 of Set 11 | marabba
# Processing Record 29 of Set 11 | emba
# Processing Record 30 of Set 11 | kuching
# Processing Record 31 of Set 11 | shreveport
# Processing Record 32 of Set 11 | te anau
# Processing Record 33 of Set 11 | miyako
# Processing Record 34 of Set 11 | ndele
# Processing Record 35 of Set 11 | saint-georges
# Processing Record 36 of Set 11 | berlevag
# Processing Record 37 of Set 11 | honningsvag
# Processing Record 38 of Set 11 | thunder bay
# Processing Record 39 of Set 11 | ciudad bolivar
# Processing Record 40 of Set 11 | kudat
# Processing Record 41 of Set 11 | khomeynishahr
# City not found. Skipping...
# Processing Record 42 of Set 11 | sosnovo-ozerskoye
# Processing Record 43 of Set 11 | millau
# Processing Record 44 of Set 11 | ramon
# Processing Record 45 of Set 11 | mikhaylovka
# Processing Record 46 of Set 11 | moron
# Processing Record 47 of Set 11 | musoma
# Processing Record 48 of Set 11 | isla mujeres
# Processing Record 49 of Set 11 | salalah
# Processing Record 0 of Set 12 | narsaq
# Processing Record 1 of Set 12 | naryan-mar
# Processing Record 2 of Set 12 | geraldton
# Processing Record 3 of Set 12 | ler
# Processing Record 4 of Set 12 | general pico
# Processing Record 5 of Set 12 | saratoga springs
# Processing Record 6 of Set 12 | miles city
# Processing Record 7 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 8 of Set 12 | plettenberg bay
# Processing Record 9 of Set 12 | jumla
# Processing Record 10 of Set 12 | cochabamba
# Processing Record 11 of Set 12 | gushikawa
# Processing Record 12 of Set 12 | barinas
# Processing Record 13 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 12 | aklavik
# Processing Record 15 of Set 12 | klyuchi
# Processing Record 16 of Set 12 | ciudad guayana
# Processing Record 17 of Set 12 | smithers
# Processing Record 18 of Set 12 | annonay
# Processing Record 19 of Set 12 | pucallpa
# Processing Record 20 of Set 12 | lyubech
# Processing Record 21 of Set 12 | buta
# Processing Record 22 of Set 12 | manokwari
# Processing Record 23 of Set 12 | dakoro
# Processing Record 24 of Set 12 | keetmanshoop
# Processing Record 25 of Set 12 | mogadishu
# Processing Record 26 of Set 12 | mercedes
# Processing Record 27 of Set 12 | arrecife
# Processing Record 28 of Set 12 | pasighat
# Processing Record 29 of Set 12 | banjar
# Processing Record 30 of Set 12 | merrill
# Processing Record 31 of Set 12 | hervey bay
# Processing Record 32 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 33 of Set 12 | anchorage
# Processing Record 34 of Set 12 | axim
# Processing Record 35 of Set 12 | bibiani
# Processing Record 36 of Set 12 | rio grande
# Processing Record 37 of Set 12 | namanyere
# Processing Record 38 of Set 12 | sola
# Processing Record 39 of Set 12 | aksaray
# Processing Record 40 of Set 12 | ushtobe
# Processing Record 41 of Set 12 | kamiiso
# Processing Record 42 of Set 12 | moindou
# Processing Record 43 of Set 12 | zabol
# Processing Record 44 of Set 12 | ratnagiri
# Processing Record 45 of Set 12 | taldan
# Processing Record 46 of Set 12 | husavik
# Processing Record 47 of Set 12 | kerema
# Processing Record 48 of Set 12 | myitkyina
# Processing Record 49 of Set 12 | coihaique
# Processing Record 0 of Set 13 | grindavik
# Processing Record 1 of Set 13 | lopsmarka
# Processing Record 2 of Set 13 | poum
# Processing Record 3 of Set 13 | rovaniemi
# Processing Record 4 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 13 | neuquen
# Processing Record 6 of Set 13 | port blair
# Processing Record 7 of Set 13 | otane
# Processing Record 8 of Set 13 | yarada
# Processing Record 9 of Set 13 | vaitape
# Processing Record 10 of Set 13 | daru
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count

city_data_df.count()
# Out:
# City          558
# Lat           558
# Lng           558
# Max Temp      558
# Humidity      558
# Cloudiness    558
# Wind Speed    558
# Country       558
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        rikitea -23.1203 -134.9692    297.26        81         100
# 1       hermanus -34.4187   19.2345    283.60        71          30
# 2      nishihara  26.1842  127.7558    294.75        64          75
# 3    grand gaube -20.0064   57.6608    300.03        70          53
# 4  mar del plata -38.0023  -57.5575    294.16        73           0
#
#    Wind Speed Country
# 0        6.06      PF
# 1        2.07      ZA
# 2       10.29      JP
# 3        4.92      MU
# 4        5.66      AR

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              rikitea -23.1203 -134.9692    297.26        81         100
# 1             hermanus -34.4187   19.2345    283.60        71          30
# 2            nishihara  26.1842  127.7558    294.75        64          75
# 3          grand gaube -20.0064   57.6608    300.03        70          53
# 4        mar del plata -38.0023  -57.5575    294.16        73           0
#
#          Wind Speed Country
# City_ID
# 0              6.06      PF
# 1              2.07      ZA
# 2             10.29      JP
# 3              4.92      MU
# 4              5.66      AR

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (2022-10-18)")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity 2022-10-18")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness 2022-10-18")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed 2022-10-18")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    plt.annotate(line_eq,(0,50), fontsize=15, color="red")
    print(f"The r-squared is: {rvalue**2}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0].head()

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2           nishihara  26.1842  127.7558    294.75        64          75
# 5        san patricio  28.0170  -97.5169    295.20        88          64
# 6                nuuk  64.1835  -51.7216    275.48        88         100
# 7           omsukchan  62.5333  155.8000    246.87        98         100
# 10           tasiilaq  65.6145  -37.6368    269.24        58           8
#
#          Wind Speed Country
# City_ID
# 2             10.29      JP
# 5              5.25      US
# 6             12.93      GL
# 7              1.67      RU
# 10             1.66      GL

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] <= 0].head()

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              rikitea -23.1203 -134.9692    297.26        81         100
# 1             hermanus -34.4187   19.2345    283.60        71          30
# 3          grand gaube -20.0064   57.6608    300.03        70          53
# 4        mar del plata -38.0023  -57.5575    294.16        73           0
# 8               hobart -42.8794  147.3294    288.85        58          75
#
#          Wind Speed Country
# City_ID
# 0              6.06      PF
# 1              2.07      ZA
# 3              4.92      MU
# 4              5.66      AR
# 8              7.72      AU

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
x_label = "Latitude"
y_label = "Max Temp"
plot_linear_regression(x_values, y_values, x_label, y_label)
plt.show()
# Out:
# The r-squared is: 0.6797242066369699

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
x_label = "Latitude"
y_label = "Max Temp"
plot_linear_regression(x_values, y_values, x_label, y_label)
plt.show()
# Out:
# The r-squared is: 0.5047825788232994

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
px_label = "Latitude"
y_label = "Humidity"
plot_linear_regression(x_values, y_values, x_label, y_label)
plt.show()
# Out:
# The r-squared is: 0.019977807197724552

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
pltx_label = "Latitude"
y_label = "Humidity"
plot_linear_regression(x_values, y_values, x_label, y_label)
plt.show()
# Out:
# The r-squared is: 0.4095528663003828

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
px_label = "Latitude"
y_label = "Cloudiness"
plot_linear_regression(x_values, y_values, x_label, y_label)
plt.show()
# Out:
# The r-squared is: 0.002581183735834254

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
x_label = "Latitude"
y_label = "cloudiness"
plot_linear_regression(x_values, y_values, x_label, y_label)
plt.show()
# Out:
# The r-squared is: 0.1332600547972014

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
x_label = "Latitude"
y_label = "Wind Speed"
plot_linear_regression(x_values, y_values, x_label, y_label)
plt.show()
# Out:
# The r-squared is: 0.06823993391122012

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
x_label = "Latitude"
y_label = "Wind Speed"
plot_linear_regression(x_values, y_values, x_label, y_label)
plt.show()
# Out:
# The r-squared is: 0.052006615811035495

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
